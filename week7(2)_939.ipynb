# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjiblama28/AI-Application-System/blob/main/week7(2)_939.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
import requests
# Save datagenerators as file to colab working directory
# If you are using GitHub, make sure you get the "Raw" version of the code
url = 'https://raw.githubusercontent.com/NVDLI/LDL/main/pt_framework/utilities.py'
r = requests.get(url)

# make sure your filename is the same as how you want to import 
with open('utilities.py', 'w') as f:
    f.write(r.text)

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader
import numpy as np
from utilities import train_model

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
EPOCHS = 128
BATCH_SIZE = 32

# Load training dataset into a single batch to compute mean and stddev.
transform = transforms.Compose([transforms.ToTensor()])
trainset = CIFAR10(root='./pt_data', train=True, download=True, transform=transform)
trainloader = DataLoader(trainset, batch_size=len(trainset), shuffle=False)
data = next(iter(trainloader))
mean = data[0].mean()
stddev = data[0].std()

# Load and standardize training and test dataset.
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize(mean, stddev)])

trainset = CIFAR10(root='./pt_data', train=True, download=True, transform=transform)
testset = CIFAR10(root='./pt_data', train=False, download=True, transform=transform)

# Model with 2 convolutional and 1 fully-connected layer.
model = nn.Sequential(
    nn.Conv2d(3, 64, 5, stride=2, padding=2), # Output is 64x16x16.
    nn.ReLU(),
    nn.Conv2d(64, 64, 3, stride=2, padding=1), # Output is 64x8x8.
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(64 * 8 * 8, 10)
)

# Retrieve layers for custom weight initialization.
layers = next(model.modules())
conv_layer0 = layers[0]
conv_layer1 = layers[2]
output_layer = layers[5]

# Kaiming (He) initialization.
nn.init.kaiming_normal_(conv_layer0.weight)
nn.init.constant_(conv_layer0.bias, 0.0)
nn.init.kaiming_normal_(conv_layer1.weight)
nn.init.constant_(conv_layer1.bias, 0.0)

# Xavier (Glorot) initialization.
nn.init.xavier_uniform_(output_layer.weight)
nn.init.constant_(output_layer.bias, 0.0)

# Loss function and optimizer
optimizer = torch.optim.Adam(model.parameters())
loss_function = nn.CrossEntropyLoss()

# Train the model.
train_model(model, device, EPOCHS, BATCH_SIZE, trainset, testset,
            optimizer, loss_function, 'acc')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./pt_data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./pt_data/cifar-10-python.tar.gz to ./pt_data
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/128 loss: 1.4046 - acc: 0.5037 - val_loss: 1.1559 - val_acc: 0.5964
# Epoch 2/128 loss: 1.0572 - acc: 0.6291 - val_loss: 1.0956 - val_acc: 0.6218
# Epoch 3/128 loss: 0.9172 - acc: 0.6805 - val_loss: 1.0415 - val_acc: 0.6374
# Epoch 4/128 loss: 0.8149 - acc: 0.7160 - val_loss: 1.0637 - val_acc: 0.6403
# Epoch 5/128 loss: 0.7349 - acc: 0.7431 - val_loss: 1.0846 - val_acc: 0.6412
# Epoch 6/128 loss: 0.6677 - acc: 0.7666 - val_loss: 1.1223 - val_acc: 0.6431
# Epoch 7/128 loss: 0.6058 - acc: 0.7878 - val_loss: 1.1532 - val_acc: 0.6429
# Epoch 8/128 loss: 0.5524 - acc: 0.8053 - val_loss: 1.1942 - val_acc: 0.6444
# Epoch 9/128 loss: 0.5056 - acc: 0.8212 - val_loss: 1.2729 - val_acc: 0.6346
# Epoch 10/128 loss: 0.4694 - acc: 0.8334 - val_loss: 1.3706 - val_acc: 0.6302
# Epoch 11/128 loss: 0.4325 - acc: 0.8460 - val_loss: 1.4245 - val_acc: 0.6317
# Epoch 12/128 loss: 0.3953 - acc: 0.8585 - val_loss: 1.5730 - val_acc: 0.6159
# Epoch 13/128 loss: 0.3689 - acc: 0.8675 - val_loss: 1.5782 - val_acc: 0.6244
# Epoch 14/128 loss: 0.3387 - acc: 0.8792 - val_loss: 1.6550 - val_acc: 0.6296
# Epoch 15/128 loss: 0.3213 - acc: 0.8840 - val_loss: 1.7692 - val_acc: 0.6220
# Epoch 16/128 loss: 0.2974 - acc: 0.8932 - val_loss: 1.8455 - val_acc: 0.6323
# Epoch 17/128 loss: 0.2754 - acc: 0.9004 - val_loss: 1.9778 - val_acc: 0.6260
# Epoch 18/128 loss: 0.2623 - acc: 0.9051 - val_loss: 2.0864 - val_acc: 0.6057
# Epoch 19/128 loss: 0.2475 - acc: 0.9107 - val_loss: 2.1882 - val_acc: 0.6209
# Epoch 20/128 loss: 0.2331 - acc: 0.9168 - val_loss: 2.3134 - val_acc: 0.6177
# Epoch 21/128 loss: 0.2237 - acc: 0.9193 - val_loss: 2.3734 - val_acc: 0.6129
# Epoch 22/128 loss: 0.2052 - acc: 0.9263 - val_loss: 2.4254 - val_acc: 0.6259
# Epoch 23/128 loss: 0.2016 - acc: 0.9270 - val_loss: 2.5981 - val_acc: 0.6016
# Epoch 24/128 loss: 0.1997 - acc: 0.9292 - val_loss: 2.6636 - val_acc: 0.6114
# Epoch 25/128 loss: 0.1830 - acc: 0.9338 - val_loss: 2.7421 - val_acc: 0.6145
# Epoch 26/128 loss: 0.1791 - acc: 0.9367 - val_loss: 2.8589 - val_acc: 0.6112
# Epoch 27/128 loss: 0.1775 - acc: 0.9369 - val_loss: 3.0068 - val_acc: 0.6148
# Epoch 28/128 loss: 0.1754 - acc: 0.9371 - val_loss: 3.0737 - val_acc: 0.6185
# Epoch 29/128 loss: 0.1675 - acc: 0.9413 - val_loss: 3.1734 - val_acc: 0.6014
# Epoch 30/128 loss: 0.1610 - acc: 0.9424 - val_loss: 3.3396 - val_acc: 0.6126
# Epoch 31/128 loss: 0.1695 - acc: 0.9412 - val_loss: 3.3123 - val_acc: 0.6080
# Epoch 32/128 loss: 0.1561 - acc: 0.9451 - val_loss: 3.5435 - val_acc: 0.6013
# Epoch 33/128 loss: 0.1550 - acc: 0.9455 - val_loss: 3.6757 - val_acc: 0.6102
# Epoch 34/128 loss: 0.1529 - acc: 0.9473 - val_loss: 3.6452 - val_acc: 0.5991
# Epoch 35/128 loss: 0.1460 - acc: 0.9511 - val_loss: 3.7222 - val_acc: 0.6075
# Epoch 36/128 loss: 0.1493 - acc: 0.9481 - val_loss: 3.8614 - val_acc: 0.6134
# Epoch 37/128 loss: 0.1496 - acc: 0.9492 - val_loss: 4.0205 - val_acc: 0.6142
# Epoch 38/128 loss: 0.1461 - acc: 0.9506 - val_loss: 4.1161 - val_acc: 0.6009
# Epoch 39/128 loss: 0.1498 - acc: 0.9506 - val_loss: 4.1021 - val_acc: 0.6065
# Epoch 40/128 loss: 0.1332 - acc: 0.9560 - val_loss: 4.2784 - val_acc: 0.6121
# Epoch 41/128 loss: 0.1494 - acc: 0.9511 - val_loss: 4.3862 - val_acc: 0.5984
# Epoch 42/128 loss: 0.1441 - acc: 0.9527 - val_loss: 4.3834 - val_acc: 0.6090
# Epoch 43/128 loss: 0.1381 - acc: 0.9550 - val_loss: 4.4987 - val_acc: 0.6050
# Epoch 44/128 loss: 0.1362 - acc: 0.9553 - val_loss: 4.5517 - val_acc: 0.6106
# Epoch 45/128 loss: 0.1402 - acc: 0.9555 - val_loss: 4.7164 - val_acc: 0.6131
# Epoch 46/128 loss: 0.1392 - acc: 0.9559 - val_loss: 4.9040 - val_acc: 0.6109
# Epoch 47/128 loss: 0.1334 - acc: 0.9585 - val_loss: 4.9627 - val_acc: 0.6083
# Epoch 48/128 loss: 0.1264 - acc: 0.9599 - val_loss: 5.0087 - val_acc: 0.6035
# Epoch 49/128 loss: 0.1423 - acc: 0.9563 - val_loss: 5.0764 - val_acc: 0.6125
# Epoch 50/128 loss: 0.1412 - acc: 0.9573 - val_loss: 5.2400 - val_acc: 0.6081
# Epoch 51/128 loss: 0.1362 - acc: 0.9595 - val_loss: 5.3179 - val_acc: 0.6038
# Epoch 52/128 loss: 0.1348 - acc: 0.9600 - val_loss: 5.3064 - val_acc: 0.6024
# Epoch 53/128 loss: 0.1294 - acc: 0.9610 - val_loss: 5.5047 - val_acc: 0.6118
# Epoch 54/128 loss: 0.1378 - acc: 0.9583 - val_loss: 5.6286 - val_acc: 0.6100
# Epoch 55/128 loss: 0.1362 - acc: 0.9613 - val_loss: 5.6974 - val_acc: 0.6078
# Epoch 56/128 loss: 0.1346 - acc: 0.9617 - val_loss: 5.6238 - val_acc: 0.6105
# Epoch 57/128 loss: 0.1269 - acc: 0.9625 - val_loss: 5.8714 - val_acc: 0.6135
# Epoch 58/128 loss: 0.1359 - acc: 0.9602 - val_loss: 5.8468 - val_acc: 0.6113
# Epoch 59/128 loss: 0.1328 - acc: 0.9627 - val_loss: 6.1833 - val_acc: 0.6116
# Epoch 60/128 loss: 0.1329 - acc: 0.9629 - val_loss: 6.1554 - val_acc: 0.6075
# Epoch 61/128 loss: 0.1317 - acc: 0.9630 - val_loss: 6.2046 - val_acc: 0.5969
# Epoch 62/128 loss: 0.1370 - acc: 0.9621 - val_loss: 6.4270 - val_acc: 0.6057
# Epoch 63/128 loss: 0.1380 - acc: 0.9619 - val_loss: 6.3224 - val_acc: 0.6068
# Epoch 64/128 loss: 0.1297 - acc: 0.9645 - val_loss: 6.4048 - val_acc: 0.6111
# Epoch 65/128 loss: 0.1348 - acc: 0.9635 - val_loss: 6.5732 - val_acc: 0.6016
# Epoch 66/128 loss: 0.1327 - acc: 0.9641 - val_loss: 6.7853 - val_acc: 0.6102
# Epoch 67/128 loss: 0.1327 - acc: 0.9655 - val_loss: 6.9367 - val_acc: 0.6135
# Epoch 68/128 loss: 0.1412 - acc: 0.9644 - val_loss: 7.1773 - val_acc: 0.6118
# Epoch 69/128 loss: 0.1287 - acc: 0.9666 - val_loss: 7.0552 - val_acc: 0.6055
# Epoch 70/128 loss: 0.1419 - acc: 0.9640 - val_loss: 6.8858 - val_acc: 0.6046
# Epoch 71/128 loss: 0.1303 - acc: 0.9665 - val_loss: 7.2537 - val_acc: 0.6086
# Epoch 72/128 loss: 0.1394 - acc: 0.9657 - val_loss: 7.3067 - val_acc: 0.6116
# Epoch 73/128 loss: 0.1228 - acc: 0.9679 - val_loss: 7.3770 - val_acc: 0.6085
# Epoch 74/128 loss: 0.1295 - acc: 0.9677 - val_loss: 7.4901 - val_acc: 0.6062
# Epoch 75/128 loss: 0.1437 - acc: 0.9652 - val_loss: 7.6540 - val_acc: 0.6077
# Epoch 76/128 loss: 0.1248 - acc: 0.9688 - val_loss: 7.8023 - val_acc: 0.6122
# Epoch 77/128 loss: 0.1346 - acc: 0.9663 - val_loss: 7.7605 - val_acc: 0.6055
# Epoch 78/128 loss: 0.1361 - acc: 0.9671 - val_loss: 7.8732 - val_acc: 0.6052
# Epoch 79/128 loss: 0.1311 - acc: 0.9679 - val_loss: 7.7658 - val_acc: 0.6109
# Epoch 80/128 loss: 0.1272 - acc: 0.9700 - val_loss: 8.1491 - val_acc: 0.6132
# Epoch 81/128 loss: 0.1201 - acc: 0.9700 - val_loss: 8.0773 - val_acc: 0.6139
# Epoch 82/128 loss: 0.1382 - acc: 0.9675 - val_loss: 8.2972 - val_acc: 0.6091
# Epoch 83/128 loss: 0.1415 - acc: 0.9681 - val_loss: 8.5461 - val_acc: 0.6117
# Epoch 84/128 loss: 0.1327 - acc: 0.9696 - val_loss: 8.5219 - val_acc: 0.6047
# Epoch 85/128 loss: 0.1301 - acc: 0.9697 - val_loss: 8.5008 - val_acc: 0.6105
# Epoch 86/128 loss: 0.1357 - acc: 0.9696 - val_loss: 8.8616 - val_acc: 0.6096
# Epoch 87/128 loss: 0.1469 - acc: 0.9682 - val_loss: 8.7747 - val_acc: 0.6057
# Epoch 88/128 loss: 0.1281 - acc: 0.9719 - val_loss: 8.9924 - val_acc: 0.6076
# Epoch 89/128 loss: 0.1410 - acc: 0.9687 - val_loss: 9.0292 - val_acc: 0.6103
# Epoch 90/128 loss: 0.1168 - acc: 0.9728 - val_loss: 9.0447 - val_acc: 0.6031
# Epoch 91/128 loss: 0.1431 - acc: 0.9687 - val_loss: 9.2018 - val_acc: 0.6030
# Epoch 92/128 loss: 0.1426 - acc: 0.9693 - val_loss: 9.3402 - val_acc: 0.6111
# Epoch 93/128 loss: 0.1359 - acc: 0.9705 - val_loss: 9.2945 - val_acc: 0.6015
# Epoch 94/128 loss: 0.1335 - acc: 0.9723 - val_loss: 9.4523 - val_acc: 0.6031
# Epoch 95/128 loss: 0.1341 - acc: 0.9711 - val_loss: 9.6415 - val_acc: 0.6021
# Epoch 96/128 loss: 0.1346 - acc: 0.9711 - val_loss: 9.6949 - val_acc: 0.6044
# Epoch 97/128 loss: 0.1345 - acc: 0.9727 - val_loss: 9.7211 - val_acc: 0.6051
# Epoch 98/128 loss: 0.1376 - acc: 0.9711 - val_loss: 10.0300 - val_acc: 0.6051
# Epoch 99/128 loss: 0.1249 - acc: 0.9734 - val_loss: 10.1160 - val_acc: 0.5954
# Epoch 100/128 loss: 0.1476 - acc: 0.9714 - val_loss: 10.3018 - val_acc: 0.6013
# Epoch 101/128 loss: 0.1377 - acc: 0.9723 - val_loss: 10.2091 - val_acc: 0.6064
# Epoch 102/128 loss: 0.1266 - acc: 0.9739 - val_loss: 10.5008 - val_acc: 0.6042
# Epoch 103/128 loss: 0.1391 - acc: 0.9718 - val_loss: 10.5880 - val_acc: 0.6034
# Epoch 104/128 loss: 0.1371 - acc: 0.9731 - val_loss: 10.8402 - val_acc: 0.6001
# Epoch 105/128 loss: 0.1436 - acc: 0.9727 - val_loss: 10.7443 - val_acc: 0.6033
# Epoch 106/128 loss: 0.1377 - acc: 0.9738 - val_loss: 10.7178 - val_acc: 0.6082
# Epoch 107/128 loss: 0.1406 - acc: 0.9730 - val_loss: 10.7469 - val_acc: 0.6022
# Epoch 108/128 loss: 0.1403 - acc: 0.9732 - val_loss: 10.9174 - val_acc: 0.6000
# Epoch 109/128 loss: 0.1495 - acc: 0.9717 - val_loss: 11.0573 - val_acc: 0.6068
# Epoch 110/128 loss: 0.1250 - acc: 0.9755 - val_loss: 11.3307 - val_acc: 0.6026
# Epoch 111/128 loss: 0.1451 - acc: 0.9727 - val_loss: 11.2395 - val_acc: 0.6063
# Epoch 112/128 loss: 0.1436 - acc: 0.9732 - val_loss: 11.5053 - val_acc: 0.6015
# Epoch 113/128 loss: 0.1289 - acc: 0.9759 - val_loss: 11.6299 - val_acc: 0.6039
# Epoch 114/128 loss: 0.1407 - acc: 0.9741 - val_loss: 11.8152 - val_acc: 0.6073
# Epoch 115/128 loss: 0.1413 - acc: 0.9742 - val_loss: 11.6623 - val_acc: 0.6037
# Epoch 116/128 loss: 0.1422 - acc: 0.9741 - val_loss: 12.0706 - val_acc: 0.6085
# Epoch 117/128 loss: 0.1298 - acc: 0.9757 - val_loss: 12.0928 - val_acc: 0.6013
# Epoch 118/128 loss: 0.1453 - acc: 0.9740 - val_loss: 11.9481 - val_acc: 0.6053
# Epoch 119/128 loss: 0.1267 - acc: 0.9769 - val_loss: 12.2464 - val_acc: 0.5978
# Epoch 120/128 loss: 0.1592 - acc: 0.9734 - val_loss: 12.1108 - val_acc: 0.6009
# Epoch 121/128 loss: 0.1316 - acc: 0.9764 - val_loss: 12.4975 - val_acc: 0.6113
# Epoch 122/128 loss: 0.1376 - acc: 0.9758 - val_loss: 12.5984 - val_acc: 0.6053
# Epoch 123/128 loss: 0.1463 - acc: 0.9741 - val_loss: 12.7143 - val_acc: 0.6039
# Epoch 124/128 loss: 0.1343 - acc: 0.9763 - val_loss: 12.8387 - val_acc: 0.6023
# Epoch 125/128 loss: 0.1417 - acc: 0.9754 - val_loss: 13.0343 - val_acc: 0.6033
# Epoch 126/128 loss: 0.1393 - acc: 0.9760 - val_loss: 13.2116 - val_acc: 0.5973
# Epoch 127/128 loss: 0.1456 - acc: 0.9755 - val_loss: 13.2375 - val_acc: 0.6020
# Epoch 128/128 loss: 0.1403 - acc: 0.9761 - val_loss: 13.4278 - val_acc: 0.6027
# [0.9761476327575176, 0.6027356230031949]
